# %%
import os
import sys
import matplotlib.pyplot as plt

sys.path.append('..')
from binance_spot_data import Historical_spot_data

# %%
hist = Historical_spot_data()

pair = "BTCUSDT"
interval = "1m"
from_date = "2022-01-01"
to_date = "2024-07-10"

df = hist.load_klines_spot_to_df(pair=pair, interval='1m', from_date=from_date, to_date=to_date)

print(df)
# Out:
# ['2022-01', '2022-02', '2022-03', '2022-04', '2022-05', '2022-06', '2022-07', '2022-08', '2022-09', '2022-10', '2022-11', '2022-12', '2023-01', '2023-02', '2023-03', '2023-04', '2023-05', '2023-06', '2023-07', '2023-08', '2023-09', '2023-10', '2023-11', '2023-12', '2024-01', '2024-02', '2024-03', '2024-04', '2024-05', '2024-06']
# downloading: https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-01.zip
# download complete
# downloading: https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-02.zip
# download complete
# downloading: https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-03.zip
# download complete
# downloading: https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-04.zip
# download complete
# downloading: https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-05.zip
# download complete
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))

df[['close']].plot(ax=ax)
# Out:
# <Axes: xlabel='open_time'>
